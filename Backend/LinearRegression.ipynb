# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv('C:/Users/mdasi/Desktop/Travel_Ease/Travel-Trails/Backend/tourism_total_cost_dataset1.csv')

# %%
df.head()
# Out:
#     State Name  Hotel Price  Self Allowance  Travel Price     Food Cost  \
# 0          Goa  9660.591412     4432.646776  10730.815620  11258.335008
# 1  West Bengal  5260.532734     2144.168672   7111.716323   4619.590053
# 2       Kerala  6983.254119     2342.513456  11887.067021   6707.667139
# 3  West Bengal  6689.997525     2024.216950   4950.538249   7407.845784
# 4  West Bengal  5828.954537     3913.002797   7962.975581   5778.145681
#
#      Total Cost
# 0  36082.388816
# 1  19136.007783
# 2  27920.501734
# 3  21072.598508
# 4  23483.078596

# %%
dummies=pd.get_dummies(df['State Name'])

# %%
dummies
# Out:
#        Goa  Kerala  Rajasthan  Sikkim  West Bengal
# 0     True   False      False   False        False
# 1    False   False      False   False         True
# 2    False    True      False   False        False
# 3    False   False      False   False         True
# 4    False   False      False   False         True
# ..     ...     ...        ...     ...          ...
# 995  False   False       True   False        False
# 996  False   False      False    True        False
# 997  False   False      False    True        False
# 998   True   False      False   False        False
# 999  False    True      False   False        False
#
# [1000 rows x 5 columns]

# %%
merged=pd.concat([df,dummies],axis=1)

# %%
merged
# Out:
#       State Name  Hotel Price  Self Allowance  Travel Price     Food Cost  \
# 0            Goa  9660.591412     4432.646776  10730.815620  11258.335008
# 1    West Bengal  5260.532734     2144.168672   7111.716323   4619.590053
# 2         Kerala  6983.254119     2342.513456  11887.067021   6707.667139
# 3    West Bengal  6689.997525     2024.216950   4950.538249   7407.845784
# 4    West Bengal  5828.954537     3913.002797   7962.975581   5778.145681
# ..           ...          ...             ...           ...           ...
# 995    Rajasthan  7687.168844     4462.287464   7537.873441  12673.820156
# 996       Sikkim  5561.109604     3139.079559   7974.236898   5421.588614
# 997       Sikkim  6401.138896     2519.083566   8694.333386   7083.551943
# 998          Goa  5208.364503     3873.991771  10324.434460   9384.529609
# 999       Kerala  3923.960080     3387.121871   9952.305832   7742.809003
#
#        Total Cost    Goa  Kerala  Rajasthan  Sikkim  West Bengal
# ...

# %%
df = merged.drop(['State Name'], axis=1)

# %%
df.head()
# Out:
#    Hotel Price  Self Allowance  Travel Price     Food Cost    Total Cost  \
# 0  9660.591412     4432.646776  10730.815620  11258.335008  36082.388816
# 1  5260.532734     2144.168672   7111.716323   4619.590053  19136.007783
# 2  6983.254119     2342.513456  11887.067021   6707.667139  27920.501734
# 3  6689.997525     2024.216950   4950.538249   7407.845784  21072.598508
# 4  5828.954537     3913.002797   7962.975581   5778.145681  23483.078596
#
#      Goa  Kerala  Rajasthan  Sikkim  West Bengal
# 0   True   False      False   False        False
# 1  False   False      False   False         True
# 2  False    True      False   False        False
# 3  False   False      False   False         True
# 4  False   False      False   False         True

# %%
features = ['Hotel Price', 'Self Allowance', 'Travel Price', 'Food Cost', 'Goa', 'Kerala', 'Rajasthan', 'Sikkim','West Bengal']

x = df[features]

y = df['Total Cost']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test,y_pred)

# %%
r2
# Out:
# 1.0

# %%
x_test
# Out:
#      Hotel Price  Self Allowance  Travel Price     Food Cost    Goa  Kerala  \
# 307  9638.761416     4391.798236  14340.209727   8397.177487   True   False
# 973  4577.905114     3359.240665   4582.915373   6073.477515  False   False
# 783  6233.487064     3495.634892   8955.414425  10019.218039  False    True
# 204  5925.664644     3523.411367  16727.029942  11575.967026   True   False
# 816  5664.788933     2493.647738   6872.741217   8403.215579  False   False
# ..           ...             ...           ...           ...    ...     ...
# 119  6180.632646     3944.141876  12304.377534   8766.087082  False   False
# 240  5199.374819     2428.191570   8592.113566  12340.959528  False    True
# 223  5169.729893     4327.579372  17837.598425   8839.950032   True   False
# 33   5261.089704     2585.644073   5145.848818   6548.670875  False   False
# 855  6515.641780     3737.414342  13978.657030  12739.719925   True   False
#
#      Rajasthan  Sikkim  West Bengal
# ...

# %%
y_test
# Out:
# 307    36767.946867
# 973    18593.538668
# 783    28703.754419
# 204    37752.072980
# 816    23434.393467
#            ...
# 119    31195.239139
# 240    28560.639482
# 223    36174.857722
# 33     19541.253471
# 855    36971.433077
# Name: Total Cost, Length: 200, dtype: float64

# %%
import joblib

# %%
joblib.dump(model,'model.joblib')
mj = joblib.load('model.joblib')
